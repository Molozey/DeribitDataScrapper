# %%
from download_utils import get_trades_by_time, process_trades
import pandas as pd

# %%
data = get_trades_by_time(start_time=pd.Timestamp('2023-12-10 00:00:00'), 
                          end_time=pd.Timestamp('2023-12-11 00:00:00'), 
                          table='trades')
data
# Out:
# Searching for left border CHANGE_ID
# low=1 high=32622395
# /Users/ivannovikov/Documents/Code/PythonProjects/DeribitDataScrapper/examples/BestAskAndBid/downloadBest.py:127: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# iterations: 1/26
# iterations: 11/26
# iterations: 21/26
# Searching for right border CHANGE_ID
# low=1 high=32622395
# iterations: 1/26
# iterations: 11/26
# iterations: 21/26
# Found CHANGE ID for time interval, getting data
# /Users/ivannovikov/Documents/Code/PythonProjects/DeribitDataScrapper/examples/BestAskAndBid/download_utils.py:138: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data_dict = process_trades(data, 
                           agg_ohlc=60, # bar length in seconds
                           # TODO: uncommaent to save data with structure
                           # save_name='test_data'
                           )
# Out:
# ...
# 100%|██████████| 4/4 [00:00<00:00, 16.32it/s]

# %%
eth = data_dict['ETH']
types = list(eth.keys())
sample = list(eth[types[1]].values())[0]['data']

# %%
eth[types[1]]
# Out:
# {'ETH_future-15Dec2023-none': {'strike': -1.0,
#   'maturity': 1702587600,
#   'data':                         open     high      low    close    volume
#   0
#   2023-12-10 00:03:00  2358.25  2358.25  2358.25  2358.25   16465.0
#   2023-12-10 00:04:00      NaN      NaN      NaN      NaN       0.0
#   2023-12-10 00:05:00      NaN      NaN      NaN      NaN       0.0
#   2023-12-10 00:06:00      NaN      NaN      NaN      NaN       0.0
#   2023-12-10 00:07:00      NaN      NaN      NaN      NaN       0.0
#   ...                      ...      ...      ...      ...       ...
#   2023-12-10 23:56:00  2381.50  2382.25  2381.50  2382.25   20020.0
#   2023-12-10 23:57:00  2382.75  2382.75  2380.50  2380.50    6600.0
#   2023-12-10 23:58:00  2382.25  2382.25  2382.25  2382.25   10000.0
#   2023-12-10 23:59:00  2382.25  2382.25  2382.25  2382.25    2230.0
#   2023-12-11 00:00:00  2382.90  2382.90  2382.90  2382.90  100000.0
#
#   [1438 rows x 5 columns]},
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=sample.index,
                open=sample['open'],
                high=sample['high'],
                low=sample['low'],
                close=sample['close'])])

fig.show()
# Out:
# <div>                            <div id="b6d8404f-24f0-4d7d-b504-2d5e14abcbfe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6d8404f-24f0-4d7d-b504-2d5e14abcbfe")) {                    Plotly.newPlot(                        "b6d8404f-24f0-4d7d-b504-2d5e14abcbfe",                        [{"close":[2358.25,null,null,null,null,null,2357.25,2356.0,2355.0,2353.0,null,2352.0,2350.75,2351.5,null,2352.75,2355.0,null,null,null,null,null,null,null,null,null,null,2355.25,2357.25,null,2357.75,2362.5,2361.25,2362.0,2362.25,2364.25,null,null,null,null,null,null,2362.0,null,null,null,null,2360.75,null,2361.75,null,null,null,null,null,null,null,null,2361.5,2362.25,null,null,null,null,null,null,2366.75,null,2368.0,2368.25,2369.25,null,null,2367.75,null,null,2367
# ...
